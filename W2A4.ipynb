# %%
a1, b1, c1, a2, b2, a3 = map(float, input("Nhập 6 hệ số điểm của sinh viên: ").split())
trung_binh = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3) / 10
print("Điểm trung bình của sinh viên: ", trung_binh)
