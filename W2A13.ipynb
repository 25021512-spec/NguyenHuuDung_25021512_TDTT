# %%
a = int(input("Nhập số nguyên dương a: "))
b = int(input("Nhập số nguyên dương b: "))
if a < 0 or b < 0:
    print("Vui lòng nhập số nguyên dương!")
else:
    print("Tích 2 số nguyên dương a và b là: ", a*b)
