# %%
bang_chu = input("Nhập bảng chữ cái thường: ")
if len(bang_chu) != 1:
    print("Vui lòng chỉ nhập một chữ cái!")
else:
    bang_chu.isupper()
    bang_chu.lower()
    print("Mã Unicode của chữ là: ", ord(bang_chu))
    print ("Bảng chữ cái in hoa là: ", bang_chu.upper())
