# %%
h = int(input("Nhập số giờ: "))
m = int(input("Nhập số phút: "))
if h > 24 or h < 0:
    print("Giờ không hợp lệ")
elif m > 60 or m < 0:
    print("Phút không hợp lệ")
else:
    giay = float(h) * 60 * 60 + float(m) * 60
    print(giay)
