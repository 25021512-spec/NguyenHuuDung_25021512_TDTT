# %%
#W3A2
a, b = list(map(int, input("Nhập hai số ngẫu nhiên: ").split()))
a = a^b
b = a^b
a = a^b
print(f"Hoán đổi hai số: {a}, {b}")

# %%
#W3A3
a = int(input("Nhập số cần kiểm tra: "))
if a&(a-1) == 0:
  print("Số là lũy thừa của 2")
else:
  print("Số không phải là lũy thừa của 2")

# %%
#W3A4
import math
a = float(input("Nhập 1 số: "))
print(f"Làm tròn {a} xuống là {math.floor(a)}")

# %%
#W3A5
import math
a = float(input("Nhập 1 số: "))
print(f"Làm tròn {a} lên là {math.ceil(a)}")

# %%
#W3A6
x = int(input("Nhập số x: "))
if x%2 == 0:
  print("Even")
else:
  print("Odd")

# %%
#W3A7
a, b = list(map(int, input("Nhập hai số nguyên: ").split()))
if a<0 and b<0:
  print("Yes")
else:
  print("No")

# %%
#W3A8
a = input("Chuỗi a: ")
b = input("Chuỗi b: ")
a.lower()
b.lower()
if len(a) > len(b):
  print("True")
else:
  print("False")

# %%
#W3A9
a, b, c = list(map(float, input("Nhập 3 số: ").split()))
if a+b>c and a+c>b and b+c>a:
    print("Đây là 3 cạnh của tam giác")
else:
    print("Đây không phải là 3 cạnh của tam giác")

# %%
#W3A10
day_so = list(map(int, input("Nhập dãy 4 số: ").split()))
max = day_so[0]
for i in day_so:
  if i > max:
    max = i
print(f"Số lớn nhất trong dãy là {max}")

# %%
#W3A11
a, b, c = list(map(float, input("Nhập 3 số: ").split()))
if a+b>c and a+c>b and b+c>a:
    if a==b==c:
      print("Tam giác đều")
    elif a==b or a==c or b==c:
      print("Tam giác cân")
    else:
      print("Tam giác thường")
else:
    print("Đây không phải là 3 cạnh của tam giác")

# %%
#W3A12
nam = int(input("Nhập năm: "))
if nam%4 == 0 and nam%100 != 0 or nam%400 == 0:
  print("Yes")
else:
  print("No")

# %%
#W3A14
a, b = list(map(float, input("Nhập 2 số: ").split()))
print(f"Phương trình bậc nhất: {a}x + {b} = 0")
if a == 0:
  if b == 0:
    print("Phương trình có vô số nghiệm")
  else:
    print("Phương trình vô nghiệm")
else:
  print(f"Phương trình có nghiệm x = {round(-b/a, 2)}")

# %%
#W3A15
diem = float(input("Nhập điểm: "))
if diem < 0:
  print("Điểm không hợp lệ")
else:
  if diem >= 8:
    print("Học sinh giỏi")
  elif diem >= 6.5:
    print("Học sinh khá")
  elif diem >= 5:
    print("Học sinh trung bình")
  else:
    print("Học sinh yếu")

# %%
#W3A16
#Làm tròn lên, tròn xuống
a = float(input("Nhập số: "))
b = a - int(a)
if b >= 0.5:
  lam_tron = int(a) +1
else:
  lam_tron = int(a)
#Làm tròn tới số gần nhất
c = int(a) + 1
if c - a < b:
  gan_nhat = c
else:
  gan_nhat = int(a)
res = list(map(str, [lam_tron, gan_nhat]))
print(", ".join(res))

# %%
#W3A17
a, b, c, d = list(map(float, input("Nhập 4 số: ").split()))
q = b/a
if b%a != 0:
  print("Công bội không là số nguyên")
else:
  if (b/a)*b == c and (b/a)*c == d:
    print(f"{a}, {b}, {c}, {d} là cấp số nhân với công bội nguyên")
  else:
    print("Dãy không phải cấp số nhân")
